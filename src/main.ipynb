# %%
import sys

try: del sys.modules['mynotebook']
except KeyError: pass

from mynotebook import jupyter_main

jupyter_main()
# Out:
# interactive(children=(ToggleButtons(description='Extracted by:', options=('CFEIntact/Plasma', 'Los Alamos/Plas…
